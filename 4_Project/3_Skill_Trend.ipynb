# %%
#Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import ast
import seaborn as sns
from datasets import load_dataset

#Load data
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()

#Data cleaning
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# %%
df_DA_US['job_posted_month'] = df_DA_US['job_posted_date'].dt.month

# %%
df_DA_US_exp = df_DA_US.explode('job_skills')

# %%
df_DA_US_pivot = df_DA_US_exp.pivot_table(index = 'job_posted_month', columns = 'job_skills', aggfunc = 'size', fill_value = 0)

# %%
df_DA_US_pivot.loc['Total'] = df_DA_US_pivot.sum()
df_DA_US_pivot
# Out:
# job_skills        airflow  airtable  alteryx  angular  ansible  apl  arch  \
# job_posted_month
# 1                      39         7      206       21        7    1     0
# 2                      35         0      203       23        4    1     0
# 3                      39         1      219        5        5    6     1
# 4                      28         1      208        8        3    7     3
# 5                      27         3      144       15        8    9     1
# 6                      39         5      188        9        4    8     3
# 7                      42         2      160        5        3    5     5
# 8                      44         2      187        5        3   10     0
# 9                      22         3      145       11        2    3     4
# 10                     29         9      144       13        2    0     3
# 11                     23         1      126        4        2    0     1
# ...

# %%
df_DA_US_pivot = df_DA_US_pivot[df_DA_US_pivot.loc['Total'].sort_values(ascending=False).index]

# %%
df_DA_US_pivot = df_DA_US_pivot.drop('Total')

# %%
df_DA_US_pivot
# Out:
# job_skills         sql  excel  tableau  python   sas     r  power bi  word  \
# job_posted_month
# 1                 4601   3592     2488    2254  1832  1513      1337   968
# 2                 3168   2587     1676    1618  1212  1045      1122   738
# 3                 3226   2661     1804    1683  1238  1141      1054   736
# 4                 3220   2549     1789    1679  1302  1038      1057   695
# 5                 2581   2118     1432    1349   972   867       860   557
# 6                 2862   2382     1628    1609   984  1017       989   721
# 7                 2609   2118     1533    1438   996   881       881   587
# 8                 3414   2731     1951    2025  1276  1271      1208   752
# 9                 2295   1801     1353    1229   856   746       820   478
# 10                2574   1922     1429    1373   960   835       921   498
# 11                2054   1533     1148    1049   792   647       682   430
# ...

# %%
DA_JOB = df_DA_US.groupby('job_posted_month').size()

# %%
df_DA_US_perc = df_DA_US_pivot.div(DA_JOB/100, axis = 0)

# %%
df_DA_US_perc = df_DA_US_perc.reset_index()

# %%
df_DA_US_perc['month_l'] = pd.to_datetime(df_DA_US_perc['job_posted_month'], format = '%m')

# %%
df_DA_US_perc
# Out:
# job_skills  job_posted_month        sql      excel    tableau     python  \
# 0                          1  54.167648  42.288674  29.291264  26.536379
# 1                          2  51.730895  42.243632  27.367734  26.420640
# 2                          3  51.881634  42.795111  29.012544  27.066581
# 3                          4  53.231939  42.139197  29.575136  27.756654
# 4                          5  51.692369  42.419387  28.680152  27.017825
# 5                          6  50.360725  41.914482  28.646841  28.312511
# 6                          7  50.163430  40.722938  29.475101  27.648529
# 7                          8  51.462165  41.166717  29.409105  30.524570
# 8                          9  49.471869  38.823022  29.165768  26.492779
# 9                         10  48.833238  36.463669  27.110605  26.048188
# 10                        11  45.332156  33.833591  25.336570  23.151622
# 11                        12  46.443830  38.326213  27.142498  27.041970
#
# ...

# %%
df_DA_US_perc['month_l'] = df_DA_US_perc['month_l'].dt.strftime('%B')
df_DA_US_perc
# Out:
# job_skills  job_posted_month        sql      excel    tableau     python  \
# 0                          1  54.167648  42.288674  29.291264  26.536379
# 1                          2  51.730895  42.243632  27.367734  26.420640
# 2                          3  51.881634  42.795111  29.012544  27.066581
# 3                          4  53.231939  42.139197  29.575136  27.756654
# 4                          5  51.692369  42.419387  28.680152  27.017825
# 5                          6  50.360725  41.914482  28.646841  28.312511
# 6                          7  50.163430  40.722938  29.475101  27.648529
# 7                          8  51.462165  41.166717  29.409105  30.524570
# 8                          9  49.471869  38.823022  29.165768  26.492779
# 9                         10  48.833238  36.463669  27.110605  26.048188
# 10                        11  45.332156  33.833591  25.336570  23.151622
# 11                        12  46.443830  38.326213  27.142498  27.041970
#
# ...

# %%
df_DA_US_perc = df_DA_US_perc.drop('job_posted_month', axis=1)

# %%
df_line = df_DA_US_perc.iloc[:,:5]
sns.lineplot(data = df_line, dashes = False)
sns.set_theme(style = 'ticks')
sns.despine()

plt.xticks(rotation = 45, ha = 'right')
plt.title('Top skills for Data analyst in the USA over 2023')
plt.ylabel('Probability')
plt.xlabel('2023')
plt.legend().remove()

from matplotlib.ticker import PercentFormatter
ax = plt.gca() 
ax.yaxis.set_major_formatter(PercentFormatter(decimals = 0))

for i in range(5):
    y_pos = df_line.iloc[-1, i]
    if df_line.columns[i] == 'python':
        y_pos += 1  
    elif df_line.columns[i] == 'tableau':
        y_pos -= 1
    plt.text(11.2, y_pos, df_line.columns[i], fontsize = 9)

plt.tight_layout()
